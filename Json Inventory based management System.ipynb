# %%
products = {
    1001 : {"name":"Lays Magic masala",               "price":20,  "quan":50,  "expiry":"20 oct 2023",  "brand":"Fritolay" , "category":"Snacks"},
    1002 : {"name":"Kurkure Masala Munch",               "price":20,   "quan":130, "expiry":"12 jan 2022",  "brand":"Kurkure",  "category":"Snacks"},
    1003 : {"name":"Pringles",           "price":86,   "quan":145, "expiry":"10 mar 2023",  "brand":"pringels", "category":"Snacks"},
    1004 : {"name":"Coca Cola",         "price":45,   "quan":130, "expiry":"23 jun 2023",  "brand":"Coca Cola", "category":"Drinks"},
    1005 : {"name":"Pepsi",             "price":45,  "quan":30,  "expiry":"30 oct 2022",  "brand":"Pepsico" ,"category":"Drinks"},
    1006 : {"name":"Thumbs Up",          "price":48,  "quan":60,  "expiry":"29 jan 2022",  "brand":"Thumbs Up", "category":"Drinks"},
    1007 : {"name":"Sprite",           "price":55,   "quan":59,  "expiry":"31 aug 2022",  "brand":"Sprite" ,"category":"Snacks"},
    1008 : {"name":"Doritos Nacho Chips Cheese flavour","price":45,   "quan":90,  "expiry":"21 feb 2022",  "brand":"Doritos" ,"category":"Snacks"},
    1009 : {"name":"Mountain Dew",        "price":60,   "quan":95,  "expiry":"28 dec 2021",  "brand":"Mountain dew", "category":"Drinks"},
    1010 : {"name":"Lotte Choco Pie",         "price":110,  "quan":95,  "expiry":"01 jun 2022",  "brand":"Lotte",  "category":"Snacks"},
    1011 : {"name":"Britania Chocolate cake", "price":120,  "quan":100, "expiry":"15 jul 2022",  "brand":"Britania", "category":"Snacks"},
    1012 : {"name":"Pillsbury cookes cake",   "price":90,   "quan":200, "expiry":"02 dec 2021",  "brand":"Pillsbury", "category":"Snacks"},
    1013 : {"name":"Kraft Oreo Soft Cake",    "price":249,  "quan":120, "expiry":"30 dec 2021",  "brand":"Ore0", "category":"Snacks"},
    1014 : {"name":"Mom's Magic Cashew",      "price":80,   "quan":180, "expiry":"19 mar 2022",  "brand":"Sunfeast", "category":"Cookies and Biscuits"},
    1015 : {"name":"Cadbury Oreo chacolate",  "price":60,   "quan":185, "expiry":"19 feb 2022",  "brand":"Cadbury", "category":"Cookies and Biscuits"},
    1016 : {"name":"Betty Croker Pancake",    "price":346,  "quan":190, "expiry":"15 jan 2022",  "brand":"Betty Croker", "category":"Cookies and Biscuits"},
    1017 : {"name":"Parle G Original",        "price":67,   "quan":140, "expiry":"13 dec 2011",  "brand":"Parle", "category":"Cookies and Biscuits"},
    1018 : {"name":"Gooday",       "price":30,   "quan":450, "expiry":"14 feb 2023",  "brand":"Britania",  "category":"Cookies and Biscuits"},
    1019 : {"name":"Bingo! Mad Angle",        "price":25,   "quan":440, "expiry":"20 dec 2023",  "brand":"Bingo!","category":"Snacks"},
    1020 : {"name":"Parle Bourbon",      "price":30,   "quan":400, "expiry":"25 jan 2024",  "brand":"Parle","category":"Cookies and Biscuits"},
    1021 : {"name":"Parle Hide and seek",    "price":45,   "quan":360, "expiry":"22 jan 2023",  "brand":"Parle","category":"Cookies and Biscuits"},
    1022 : {"name":"Oreo Chocolate  ",     "price":40,   "quan":60,  "expiry":"20 dec 2024",  "brand":"Cadbury", "category":"Cookies and Biscuits"},
    1023 : {"name":"Milano",        "price":55,   "quan":70,  "expiry":"20 jun 2023",  "brand":"Parle","category":"Cookies and Biscuits"},
    1024 : {"name":"Sunfeast Dark Fantasy",               "price":65,   "quan":60,  "expiry":"22 jul 2023",  "brand":"Sunfeast","category":"Cookies and Biscuits"},
    1025 : {"name":"Fanta",      "price":89,   "quan":40,  "expiry":"20 nov 2023",  "brand":"Fanta","category":"Drinks"},
    1026 : {"name":"Marie Gold",        "price":215,  "quan":55,  "expiry":"20 jun 2024",  "brand":"Parle", "category":"Cookies and Biscuits"},
    1027 : {"name":"Pepsodent Gum Care",      "price":300,  "quan":150, "expiry":"15 jul 2022",  "brand":"Pepsodent","category":"Household"},
    1028 : {"name":"Dabur Amla Hair Oil",     "price":247,  "quan":100, "expiry":"10 aug 2024",  "brand":"DABUR","category":"HOusehold"},
    1029 : {"name":"Nivea Men Face Wash",     "price":149,  "quan":98,  "expiry":"31 jul 2022",  "brand":"Nivea","category":"HOusehold"},
    1030 : {"name":"Himalaya Herbal Face wash","price":104, "quan":200, "expiry":"22 may 2022",  "brand":"Himalaya","category":"HOusehold"},
    1031 : {"name":"Himalaya Baby Powder",    "price":243,  "quan":150, "expiry":"31 may 2024",  "brand":"Himalaya","category":"HOusehold"},
    1032 : {"name":"Nivea Talcum Powder",     "price":199,  "quan":120, "expiry":"31 may 2024",  "brand":"Nivea","category":"HOusehold"},
    1033 : {"name":"Fogg Xtremo Scent",       "price":299,  "quan":155, "expiry":"01 jan 2024",  "brand":"FOGG","category":"HOusehold"},
    1034 : {"name":"Villain Perfume men",     "price":555,  "quan":230, "expiry":"31 may 2024",  "brand":"Villian","category":"HOusehold"},
    1035 : {"name":"Colgate Toothpaste Max fresh",         "price":475,  "quan":50,  "expiry":"31 jan 2022",  "brand":"Cadbury","category":"HOusehold"},
    1036 : {"name":"Lifebuoy soap",         "price":100,  "quan":50,  "expiry":"31 jan 2022",  "brand":"Lifebuoy","category":"HOusehold"},
    1037 : {"name":"Dettol Soap",         "price":100,  "quan":50,  "expiry":"31 jan 2022",  "brand":"Dettol","category":"HOusehold"},
    1038 : {"name":"Harpic Toilet cleaner",         "price":250,  "quan":50,  "expiry":"31 jan 2022",  "brand":"Harpic","category":"HOusehold"},
    1039 : {"name":"Lux soap",         "price":100,  "quan":50,  "expiry":"31 jan 2022",  "brand":"Lux","category":"HOusehold"},
    1040 : {"name":"Santoor",         "price":125,  "quan":50,  "expiry":"31 jan 2022",  "brand":"santoor","category":"HOusehold"},
    1041 : {"name":"Cadbury Dairy milk silk",         "price":120,  "quan":50,  "expiry":"31 jan 2022",  "brand":"Cadbury","category":"Chocolates"},
    1042 : {"name":"Cadbury Dairy Milk",         "price":20,  "quan":1000,  "expiry":"31 jan 2022",  "brand":"Cadbury","category":"Chocolates"},
    1043 : {"name":"Cadbury 5 star",         "price":25,  "quan":100,  "expiry":"31 jan 2022",  "brand":"Cadbury","category":"Chocolates"},
    1044 : {"name":"Cadbury Celebrations",         "price":150,  "quan":50,  "expiry":"31 jan 2022",  "brand":"Cadbury","category":"Chocolates"},
    1045 : {"name":"Nestle maggi",         "price":120,  "quan":50,  "expiry":"31 jan 2022",  "brand":"Nestle","category":"Snacks"},
    1046 : {"name":"Nestle kit kat",         "price":25,  "quan":50,  "expiry":"31 jan 2022",  "brand":"Nestle","category":"Chocolates"},
    1047 : {"name":"Chings Chinese hakka noodles",         "price":120,  "quan":50,  "expiry":"31 jan 2022",  "brand":"Chings","category":"Snacks"},
    1048 : {"name":"Maggie Pazzta",         "price":120,  "quan":50,  "expiry":"31 jan 2022",  "brand":"Maggie","category":"Snacks"},
    1049 : {"name":"Kisaan ketchup",         "price":120,  "quan":50,  "expiry":"31 jan 2022",  "brand":"Kissan","category":"Food"},
    1050 : {"name":"Chings Soya sauce",         "price":120,  "quan":50,  "expiry":"31 jan 2022",  "brand":"Chings","category":"Food"},

}

# %%
products
# Out:
# {1001: {'name': 'Lays Magic masala',
#   'price': 20,
#   'quan': 50,
#   'expiry': '20 oct 2023',
#   'brand': 'Fritolay',
#   'category': 'Snacks'},
#  1002: {'name': 'Kurkure Masala Munch',
#   'price': 20,
#   'quan': 130,
#   'expiry': '12 jan 2022',
#   'brand': 'Kurkure',
#   'category': 'Snacks'},
#  1003: {'name': 'Pringles',
#   'price': 86,
#   'quan': 145,
#   'expiry': '10 mar 2023',
#   'brand': 'pringels',
#   'category': 'Snacks'},
#  1004: {'name': 'Coca Cola',
#   'price': 45,
#   'quan': 130,
#   'expiry': '23 jun 2023',
#   'brand': 'Coca Cola',
#   'category': 'Drinks'},
#  1005: {'name': 'Pepsi',
#   'price': 45,
#   'quan': 30,
#   'expiry': '30 oct 2022',
#   'brand': 'Pepsico',
#   'category': 'Drinks'},
#  1006: {'name': 'Thumbs Up',
#   'price': 48,
#   'quan': 60,
#   'expiry': '29 jan 2022',
#   'brand': 'Thumbs Up',
#   'category': 'Drinks'},
#  1007: {'name': 'Sprite',
#   'price': 55,
#   'quan': 59,
#   'expiry': '31 aug 2022',
#   'brand': 'Sprite',
# ...

# %% [markdown]
# # IMPORTING JSON

# %%
import json

# %%
js=json.dumps(products)
file=open("products.json","w")
file.write(js)
file.close()

# %% [markdown]
# # INSERTING NEW PRODUCTS

# %%
product_id=(input("Enter a Product Id for the new product you want to insert : "))
name=(input("Enter the name of the PRODUCT : "))
price=(input("Enter the price of the product : "))
quantity=(input("Enter the total Quantity of the product present"))
brand=(input("Enter the Brand of which the product belongs : "))
expiry=input("Enter the expiry date : ")
category=(input("Enter the category of the product which it belongs : "))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27692/1435469870.py in <module>
#       1 product_id=(input("Enter a Product Id for the new product you want to insert : "))
# ----> 2 name=(input("Enter the name of the PRODUCT : "))
#       3 price=(input("Enter the price of the product : "))
#       4 quantity=(input("Enter the total Quantity of the product present"))
#       5 brand=(input("Enter the Brand of which the product belongs : "))
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1008             self._parent_ident["shell"],
#    1009             self.get_parent("shell"),
# -> 1010             password=False,
#    1011         )
#    1012
#
# ...

# %%
print("product_id = "+ product_id+"\n"+"name = "+ name +"\n"+ "price = "+ price+"\n"+ "quantity = "+ quantity +"\n" +" expiry = " + expiry +"\n"" brand = " + brand +"\n" + "category = "+ category)
# Out:
# product_id = 1002
# name = Kurkure Masala Munch
# price = 20
# quantity = 130
#  expiry = 12 jan 2022
#  brand = Kurkure
# category = Snacks

# %% [markdown]
# # DISPLAYING THE PREVIOUS RECORDS

# %%
fp = open("products.json", "r")
data = fp.read()
fp.close()

prev_records = json.loads(data)

# %%
prev_records[product_id]
# Out:
# {'name': 'Kurkure Masala Munch',
#  'price': 20,
#  'quan': 130,
#  'expiry': '12 jan 2022',
#  'brand': 'Kurkure',
#  'category': 'Snacks'}

# %% [markdown]
# # Inserting new records in the products.json file or updating if the product id is already existing

# %%
def add_new_inventory():
    
    # taking input from the user
    product_id=(input("Enter a Product Id for the new product you want to insert : "))
    name=(input("Enter the name of the PRODUCT : "))
    price=(input("Enter the price of the product : "))
    quantity=(input("Enter the total Quantity of the product present"))
    brand=(input("Enter the Brand of which the product belongs : "))
    expiry=input("Enter the expiry date : ")
    category=(input("Enter the category of the product which it belongs : "))
    print("product_id = "+ product_id+"\n"+"name = "+ name +"\n"+ "price = "+ price+"\n"+ "quantity = "+ quantity +"\n" +" expiry = " + expiry +"\n"" brand = " + brand +"\n" + "category = "+ category)
    fp = open("products.json", "r")
    data = fp.read()
    fp.close()
    prev_records = json.loads(data)
    if (product_id in prev_records.keys()):
        prev_records[product_id]['quan'] += quantity
    else:
        prev_records[product_id] = { 'name': name,
                                 'quan': quantity,
                                 'price': price,
                                 'brand': brand,
                                 'Expiry': expiry,
                                 'Category': category}
    data = json.dumps(prev_records)
    fp = open("products.json", 'w')
    fp.write(data)
    fp.close()
choice=True
while choice:
    add_new_inventory()
    a = (input("do you want to add another record? (y/N )"))
    if (a=='N' or a=='n'):
        choice=False
        break

# %% [markdown]
# # DISPLAYING THE NEWLY ADDED RECORDS

# %%
fp = open("products.json", "r")
data = fp.read()
fp.close()

prev_records = json.loads(data)

# %%
prev_records['1051']
# Out:
# {'name': 'Haldiram Sev',
#  'quan': '5050',
#  'price': '250',
#  'brand': 'haldiram',
#  'Expiry': '23 jun 2022',
#  'Category': 'Snacks'}
